# %% [markdown]
# <a href="https://colab.research.google.com/github/leopauls/UCL-COMP0043/blob/main/UCL_COMP0043_Assignment_1_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![COMP0043_assignment1_page-0001.jpg](data:image/jpeg;base64,...)![COMP0043_assignment1_page-0002.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as r

# %%
# Q.1.


# gaussian distrib param
MEAN = 0
SIGMA = 0.5
PI = 3.14159265358979323846264338


x = np.linspace(-5,5,100)
y = (1/(SIGMA * np.sqrt(2*PI))) * np.exp((-1/2)*(np.square(x-MEAN)/SIGMA))


# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')


# plot the function
plt.plot(x,y, 'r')

# show the plot
plt.show()

""" 
Now plotted the Prob Density Function (PDF) of a Gaussian distrib. 
"""
# Out:
# ' \nNow plotted the Prob Density Function (PDF) of a Gaussian distrib. \n'

# %%
# plotting CDF

def plot_cdf():
  # plot cdf / integration of function
# Out:
#   File "<ipython-input-3-d28540143060>", line 10
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
# Q.2. 

# param

N = 3
A = []
B = []


# matrice gen funct

def gen_square_matrice(A, n):
  # n integer, A matrice

  for row in range(n):
    CURRENT_ROW = []
    for col in range(n):
      CURRENT_ROW.append(r.randint(-10,10))
    A.append(CURRENT_ROW)
  return A

A = gen_square_matrice(A, N)
B = gen_square_matrice(B, N)

print(A)
print(B)
# Out:
# [[4, -10, 2], [-4, 4, -6], [-5, 1, 9]]
# [[-6, 8, 1], [3, 4, -8], [0, 4, 0]]

# %%
# 2.a. - Built-in function:
C = np.matmul(A,B)
print(C)
# Out:
# [[-54   0  84]
#  [ 36 -40 -36]
#  [ 33   0 -13]]

# %%
# 2.b. - Coded version

def multiply_matrices(A, B, n):
  # n is the dimentions of square matr A * B
  # first lets iterate through rows and then individual numbers in the row
  # Outs matrice n by n
  out = []
  for i in range(n):
    CURRENT_ROW = []
    for j in range(n):
      # now lets go through em numbers
      CUR_NUM = 0
      for k in range(n): 
        CUR_NUM += A[i][k] * B[:i][k]
      CURRENT_ROW.append(CUR_NUM)
    out.append(CURRENT_ROW)
  return out



print(A)

print(B)

print(multiply_matrices(A,B, N))
# Out:
# [[4, -10, 2], [-4, 4, -6], [-5, 1, 9]]
# [[-6, 8, 1], [3, 4, -8], [0, 4, 0]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-d163248ced35> in <module>
#      23 print(B)
#      24
# ---> 25 print(multiply_matrices(A,B, N))
#
# <ipython-input-8-d163248ced35> in multiply_matrices(A, B, n)
#      12       CUR_NUM = 0
#      13       for k in range(n):
# ---> 14         CUR_NUM += A[i][k] * B[:i][k]
#      15       CURRENT_ROW.append(CUR_NUM)
#      16     out.append(CURRENT_ROW)
#
# IndexError: list index out of range
